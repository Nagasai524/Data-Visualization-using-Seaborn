# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
auto=pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0             two  convertible          rwd           front        88.6
# 1             two  convertible          rwd           front        88.6
# 2             two    hatchback          rwd           front        94.5
# 3            four        sedan          fwd           front        99.8
# 4            four        sedan          4wd           front        99.4
#
#    ...    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# symboling              201 non-null int64
# normalized_losses      201 non-null int64
# make                   201 non-null object
# fuel_type              201 non-null object
# aspiration             201 non-null object
# number_of_doors        201 non-null object
# body_style             201 non-null object
# drive_wheels           201 non-null object
# engine_location        201 non-null object
# wheel_base             201 non-null float64
# length                 201 non-null float64
# width                  201 non-null float64
# height                 201 non-null float64
# curb_weight            201 non-null int64
# engine_type            201 non-null object
# number_of_cylinders    201 non-null object
# engine_size            201 non-null int64
# fuel_system            201 non-null object
# bore                   201 non-null float64
# ...

# %%
auto.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
auto.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# # <center>Univariate Analysis</center>

# %% [markdown]
# # <center>Dist Plot (Histogram + KDE (Kernel Density Estimation)+Rug Plot) </center>
# ### <center> checking the distribution of features in the dataset using distplot </center>

# %% [markdown]
# #### Distplot plots the histogram of the given feature along with the kernel density estimation curve.

# %%
sns.distplot(auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(auto.normalized_losses)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='normalized_losses', ylabel='Density'>

# %% [markdown]
# # <center> Histograms with rug plot <center>

# %% [markdown]
# #### Histograms in seaborn are plotted using distplot itself. Disabling the argument kde which generates the kernel density estimate will plot the histogram. </br> The argument rug when enabled, the frequency within each bin will be displayed using the small sticks at the bottom of each bar

# %%
sns.distplot(auto.price,kde=False,rug=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# # <center> Histogram </center>

# %%
sns.distplot(auto.price,kde=False,rug=False)
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# # <center> Probability Density Function </center>

# %%
sns.distplot(auto.price,hist=False,rug=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # <center> Bi-Variate Analysis </center>

# %% [markdown]
# # <center> Scatter plot </center>

# %% [markdown]
# #### Scatter plots can also be used for categorical data but they are mainly used for reprsenting numerical data. This scatter plot is plotted using two different function in seaborn. They are
# 1. relplot (Figure level function)
# 2. scatterplot (Axes level function)
#
# #### When the argument "style" is used, different markers are used for representing each unique type of the column that is passed.
# #### The "size" parameter is used to define the marker size and it will be based on the column that is passed to the argument.
# #### The "style" parameter can be used to display data in an extra dimensions (features).

# %%
plt.style.use('fivethirtyeight')
sns.relplot(x='city_mpg',y='price',data=auto,hue='engine_type',style='fuel_type',size='highway_mpg')

# %% [markdown]
# #### The above plot is displaying the information of 5 different features of the dataframe. They are
# 1. city_mpg on x-axis
# 2. price on y-axis
# 3. engine_type being displayed using hue parameter with the help of different colors for each engine type.
# 4. highway_mpg is represented using size parameter
# 5. fuel_type is denoted using different markers.

# %%
# we can specify the custom sizes of the markers using the "sizes" parameter..
sns.relplot(x='city_mpg',y='price',data=auto,hue='engine_type',style='fuel_type',size='highway_mpg',sizes=(20,200))

# %% [markdown]
# #### All the above plots can also be generated using scatterplot function as follows

# %%
sns.scatterplot(x='city_mpg',y='price',data=auto,hue='engine_type',size='highway_mpg',sizes=(20,200))
# Out:
# <AxesSubplot:xlabel='city_mpg', ylabel='price'>

# %% [markdown]
# # <center> Joint Plots (Bi-Variate Analysis + Univariate Analysis) </center>

# %%
sns.jointplot(auto.engine_size,auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # <center> Hexbin plots </center>

# %% [markdown]
# #### Hexbin plots are similar to scatter plots where the plotted points are converted into regions of Hexagons. The Hexagon with highest density will be brighter than other histograms. The strenght of the color of hexagon represents the density of observation in that region.

# %%
sns.jointplot(auto.engine_size,auto.price,kind='hex')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # <center> Kernel Density Estimation</center>

# %%
sns.jointplot(auto.engine_size,auto.price,kind='kde')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # <center> Residual plot </center>

# %% [markdown]
# #### Residual plots are used to plot the loss obtained after fitting an liner regression model. Residual is nothing but the difference between the actual value and the predicted value.

# %%
sns.jointplot(auto.engine_size,auto.price,kind='resid')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # <center> Regression Plot </center>

# %%
sns.jointplot(auto.engine_size,auto.price,kind='reg')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # <center>Pair Wise Relationship between Multiple features</center>
# ## <center> Pair Plot (Multiple Pairwise Bivariate Distributions)</center>

# %% [markdown]
# #### In a pairplot the plots between all combinations of features that are passed as inputs will be created. In the diagnol we will end up plotting between same feature and hence we will have histogram of the features in the diagnol. Hence univariate analysis can be found on the diagnol elements and the non-diagnol plots represent Bi-variate Analysis.

# %%
sns.pairplot(auto[['city_mpg', 'engine_size', 'horsepower']])

# %% [markdown]
# ### Pair Plot with inclusion of Hue parameter

# %%
sns.pairplot(auto[['city_mpg', 'engine_size', 'horsepower','fuel_type']],hue='fuel_type')

# %% [markdown]
# ### Custom Pair Plots. (Plotting only that are required.)

# %%
sns.pairplot(x_vars=['city_mpg', 'engine_size', 'horsepower','bore'],y_vars='price',data=auto)

# %% [markdown]
# # <center>Plotting with categorical data </center>

# %% [markdown]
# ### catplot is used to plot the categorical data which is an figure level function.
# # <center> Categorical Scatter Plots</center>
# ## <center> Strip Plot </center>
# #### Both the stripplot and swarm plot comes in this sections. These plots requires atleast one categorical feature as input.

# %%
sns.stripplot(auto.engine_location,auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='engine_location', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.stripplot(auto.make,auto.price)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# The jitter argument when enabled discards the plotting of redudant points and thereby plots looks like a straigh line.
sns.stripplot(auto.engine_location,auto.price,jitter=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='engine_location', ylabel='price'>

# %% [markdown]
# # <center> Swarm plot</center>

# %% [markdown]
# #### Swarm plot displays the redudant points (y values) in a straight lines and enables us to have a look at the frequency of observations at each Y value.

# %%
sns.swarmplot(auto.number_of_doors,auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='number_of_doors', ylabel='price'>

# %%
sns.swarmplot(auto.engine_type,auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 30.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='engine_type', ylabel='price'>

# %% [markdown]
# # <center> Categorical Distribution Plots </center>

# %% [markdown]
# # <center> Box plot</center>
# <img src='five-summary.png' alt="Five Number summary using Boxplot">

# %%
sns.boxplot(auto.price)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot( auto['engine_type'],auto['price'], hue=auto['fuel_type'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='engine_type', ylabel='price'>

# %%
sns.catplot(x='number_of_doors',y='price',hue='engine_type',data=auto,kind='box')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# # <center> Violon Plot (Box Plot + KDE (PDF)) </center>
# <img src="violon.jpeg" alt="Five Number Summary using Vilon Plot"/>
# <img src="box-vilon.png" alt="Comparison of Box plot and Vilon Plot"/>

# %%
sns.violinplot(auto["price"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='price'>

# %%
sns.catplot(x='fuel_type',y='price',data=auto,kind='violin')

# %% [markdown]
# #### The KDE or PDF of the variable that is on the both side of the rectangular bar is symetric in nature. In other words, one is the duplicate of the other. This is like displaying the redundant information to the user. This becomes more concern when a hue paramter is used. When hue is used, we will have vilon plots for each unique value of that featue because of which we may run out of space. In such a case, we can enable the splot argument. This argument displays the PDF of two unique values of the feature in the same vilon instead of creating an other.

# %%
sns.catplot(x='fuel_type',y='price',hue='engine_location',data=auto,kind='violin')

# %%
sns.catplot(x='fuel_type',y='price',hue='engine_location',data=auto,kind='violin',split=True)

# %% [markdown]
# #### The split function will work only when the hue has two different levels. In other words the total number of unique values in the X feature should be equal to two.

# %% [markdown]
# # <center> Categorical Estimate Plots </center>
# ## <center> Bar plot </center>

# %% [markdown]
# #### In a barplot, the mean of the feature that is used for y-axis will be considered by default. This can be changed by passing the required function as input to the estimator argument. Bar plot also includes zero in the quantitative axis range.

# %%
sns.barplot(x='engine_type',y='price',data=auto,hue='number_of_doors')
# Out:
# <AxesSubplot:xlabel='engine_type', ylabel='price'>

# %%
sns.barplot(x='engine_type',y='price',data=auto,hue='number_of_doors',estimator=np.median)
# Out:
# <AxesSubplot:xlabel='engine_type', ylabel='price'>

# %% [markdown]
# # <center> Count Plot </center>

# %% [markdown]
# #### Count Plot can be used to plot the frequency of each unique value in a categorical column.

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='make',data=auto,hue='number_of_doors')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# # <center> Pointplot </center>

# %% [markdown]
# #### Pointplot is similar to the bar plot without rectangles and the vertical lines at each point represent the confidence intervals. Similar to Bar plot even pointplot considers the mean of the feature on the y axis.

# %%
sns.pointplot(auto['fuel_system'], auto['price'],hue=auto['number_of_doors'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='fuel_system', ylabel='price'>

# %%
sns.pointplot(auto['fuel_system'], auto['price'],hue=auto['engine_type'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='fuel_system', ylabel='price'>

# %% [markdown]
# # <center> Categorical Categorical Plots </center>
# ## <center> Heat Map </center>
# #### For creating a Heat map, we require pivot table similar to the expected heat map. Hence, Pivot table must be created fast and the created pivot table will be passed as an input argument to the heatmap function
# 1. cbar=True (enables the presence of color indicator on the right).
# 2. linewidths = integer (Can be tought of padding to each cell of table.)
# 3. cmap = theme of colors to be used in the heat map.
# 4. annot= True (This will insert the value in every box of the heat map. Null values are not replaced with anything.)

# %%
x=auto.pivot_table(index='engine_type',columns='number_of_doors',values='price',aggfunc=np.mean)
sns.heatmap(x,annot=True,linewidths=5,cmap='summer')
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='engine_type'>

# %%
x=auto.pivot_table(index='make',columns='body_style',values='price',aggfunc=np.mean)
sns.heatmap(x,cmap='winter',annot=True,linewidths=0.5,cbar=False)
# Out:
# <AxesSubplot:xlabel='body_style', ylabel='make'>

# %% [markdown]
# ### Heat map for Total number of passenger in a given year and month using Flights dataset of Searborn

# %%
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,8))
pivot=flights.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')
sns.heatmap(pivot,linewidths=0.5,cmap='viridis',annot=True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# # <center> Cluster Maps (Heat Maps + Clustering of Rows and Columns)</center>
# ### Similar rows and columns are grouped together and the order of grouping is explained by the graphs on the top. We can enable or disable either row clustering or column clustering. When both are disable the cluster map will be equivalent to Heat map. All arguments of Heat map also work with Cluster map
# Arguments
# -------------
# 1. z_score = 0 (Normalizes the values to be between -1 and 1)
# 2. metric = 'euclidean' (The distance metric using which clustering is performed. This can be changed to any kind of distance like minkowski,manhatten and so on.)
# 3. row_cluster = False (Disables the clustering of rows)
# 4. col_cluster = False (Disables the clustering of columns)

# %%
sns.clustermap(pivot,z_score=0,metric='minkowski',row_cluster=False,annot=True)

# %%
sns.clustermap(pivot,metric='correlation',col_cluster=False,annot=True)

# %% [markdown]
# # <center> Multi Panel Categorical plots </center>
# ## <center> Factor Plots </center>

# %% [markdown]
# #### In factor plots, the plot that is being created will be created for all the unique values present in the feature passed to the col attribute.

# %%
sns.factorplot(x="engine_type", y="price", col="number_of_doors", data=auto, kind="swarm")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Plotting all kinds of possible factor plots

# %%
kinds=['point', 'bar', 'box', 'violin', 'strip']
for kind in kinds:
    sns.factorplot(x="engine_type", y="price", col="number_of_doors", data=auto, kind=kind)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# # <center> Regression Plots </center>

# %% [markdown]
# #### Regression plots are used to plot the regression line without creating a Linear regression model. These plots can be used find the existence of linear relationship between two variables. These are similar to regplots.

# %%
sns.lmplot(x='engine_size',y='price',data=auto)

# %%
sns.lmplot(x='engine_size',y='price',data=auto,hue='engine_type')
